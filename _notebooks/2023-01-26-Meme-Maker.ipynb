# %%
from PIL import Image, ImageDraw, ImageFont
import textwrap

im = Image.open("/home/ronit/vscode/tri-2-csp/images/meme.jpg") 
draw = ImageDraw.Draw(im)

image_width, image_height = im.size

font = ImageFont.truetype(font="/home/ronit/vscode/tri-2-csp/impact/impact.ttf", size=int(image_height/10))

top_text = "When CSP individual reviews are soon"
bottom_text = "and I only have 4 commits"
top_text = top_text.upper()
bottom_text= bottom_text.upper()


char_width, char_height = font.getsize('A')

chars_per_line = image_width // char_width

top_lines = textwrap.wrap(top_text, width=chars_per_line)
bottom_lines = textwrap.wrap(bottom_text, width=chars_per_line)

y= 10
for line in top_lines:
    line_width, line_height = font.getsize(line)
    x=(image_width - line_width)/2
    draw.text((x,y), line, fill=asW'white', font=font)
    y += line_height

y = image_height - char_height * len(bottom_lines) - 15
for line in bottom_lines:
    line_width, line_height = font.getsize(line)
    x=(image_width - line_width)/2
    draw.text((x,y), line, fill='white', font=font)
    y += line_height
im.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=302x163 at 0x7FC4964F3D00>
